# %% [markdown]
# <a href="https://colab.research.google.com/github/Anchayadav/AutoTS/blob/main/Job_Recoomendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from wordcloud import WordCloud ,STOPWORDS,ImageColorGenerator
import string
import nltk
import re
from nltk.corpus import stopwords

data=pd.read_csv('jobs.csv')
print(data.head())
# Out:
#    Unnamed: 0                    Job Salary Job Experience Required  \
# 0           0   Not Disclosed by Recruiter               5 - 10 yrs
# 1           1   Not Disclosed by Recruiter                2 - 5 yrs
# 2           2   Not Disclosed by Recruiter                0 - 1 yrs
# 3           3       2,00,000 - 4,00,000 PA.               0 - 5 yrs
# 4           4   Not Disclosed by Recruiter                2 - 5 yrs
#
#                                           Key Skills  \
# 0                      Media Planning| Digital Media
# 1   pre sales| closing| software knowledge| clien...
# 2   Computer science| Fabrication| Quality check|...
# 3                                  Technical Support
# 4   manual testing| test engineering| test cases|...
#
#                                 Role Category  \
# 0                                 Advertising
# 1                                Retail Sales
# 2                                         R&D
# ...

# %%
data =data.drop('Unnamed: 0' ,axis=1)

# %%
data.isnull().sum()
# Out:
# Job Salary                 0
# Job Experience Required    0
# Key Skills                 0
# Role Category              1
# Functional Area            1
# Industry                   1
# Job Title                  1
# dtype: int64

# %%
text = ' '.join(i for i in data['Key Skills'])
stopwords =set(STOPWORDS)
wordclod=WordCloud(stopwords=stopwords,background_color='white').generate(text)
plt.figure(figsize=(15,10))
plt.imshow(wordclod,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text = ' '.join(i for i in data['Functional Area'])
stopwords =set(STOPWORDS)
wordcloud=WordCloud(stopwords=stopwords,background_color='white').generate(text)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b9129e58f3cb> in <cell line: 1>()
# ----> 1 text = ' '.join(i for i in data['Functional Area'])
#       2 stopwords =set(STOPWORDS)
#       3 wordcloud=WordCloud(stopwords=stopwords,background_color='white').generate(text)
#       4 plt.figure(figsize=(15,10))
#       5 plt.imshow(wordcloud,interpolation='bilinear')
#
# TypeError: sequence item 14938: expected str instance, float found

# %%
text=" ".join(i for i in data['Job Title'])
stopwords=set(STOPWORDS)
wordcloud =WordCloud(stopwords=stopwords,background_color='white').generate(text)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-74a6a6ba64e2> in <cell line: 1>()
# ----> 1 text=" ".join(i for i in data['Job Title'])
#       2 stopwords=set(STOPWORDS)
#       3 wordcloud =WordCloud(stopwords=stopwords,background_color='white').generate(text)
#       4 plt.figure(figsize=(15,10))
#       5 plt.imshow(wordcloud,interpolation='bilinear')
#
# TypeError: sequence item 14938: expected str instance, float found

# %%
from sklearn.feature_extraction import text
feature = data["Key Skills"].tolist()
tfidf =text.TfidfVectorizer(input=feature,stop_words="english")
tfidf_matrix = tfidf.fit_transform(feature)
similariity= cosine_similarity(tfidf_matrix)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-9-3dfcba35d92c> in <cell line: 4>()
#       2 feature = data["Key Skills"].tolist()
#       3 tfidf =text.TfidfVectorizer(input=feature,stop_words="english")
# ----> 4 tfidf_matrix = tfidf.fit_transform(feature)
#       5 similariity= cosine_similarity(tfidf_matrix)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2131             sublinear_tf=self.sublinear_tf,
#    2132         )
# -> 2133         X = super().fit_transform(raw_documents)
#    2134         self._tfidf.fit(X)
#    2135         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1367             )
#    1368
# -> 1369         self._validate_params()
# ...

# %%
data=pd.Series(data.index,index=data['Job Title']).drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# ...
