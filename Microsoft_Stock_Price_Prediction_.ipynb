# %% [markdown]
# <a href="https://colab.research.google.com/github/Anchayadav/AutoTS/blob/main/Microsoft_Stock_Price_Prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.style.use('fivethirtyeight')

data=pd.read_csv('MSFT.csv')
print(data.head())
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061434  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063628   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.064725   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063079    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.061982    47894400

# %%
plt.figure(figsize=(10,4))
plt.title('microsoft stock price')
plt.xlabel('Date')
plt.ylabel('Close')
plt.plot(data['Close'])
plt.show()

# %%
print(data.corr)
sns.heatmap(data.corr())
plt.show()
# Out:
# <bound method DataFrame.corr of             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061434
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063628
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064725
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.063079
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061982
# ...          ...         ...         ...         ...         ...         ...
# 9078  2022-03-18  295.369995  301.000000  292.730011  300.429993  300.429993
# 9079  2022-03-21  298.890015  300.140015  294.899994  299.160004  299.160004
# 9080  2022-03-22  299.799988  305.000000  298.769989  304.059998  304.059998
# 9081  2022-03-23  300.510010  303.230011  297.720001  299.489990  299.489990
# 9082  2022-03-24  299.140015  304.200012  298.320007  304.100006  304.100006
#
# ...

# %%
x= data[['Open','High','Low']]
y=data['Close']
x=x.to_numpy()
y=y.to_numpy()
y=y.reshape(-1,1)

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
model= DecisionTreeRegressor()
model.fit(xtrain,ytrain)
ypred= model.predict(xtest)
data=pd.DataFrame(data={"prediction Rate": ypred})
print(data)
# Out:
#       prediction Rate
# 0           46.680000
# 1           28.375000
# 2            4.445313
# 3           25.940001
# 4          147.309998
# ...               ...
# 1812        33.299999
# 1813         1.992188
# 1814        39.970001
# 1815        33.390625
# 1816        26.809999
#
# [1817 rows x 1 columns]
