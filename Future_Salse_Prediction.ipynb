# %% [markdown]
# <a href="https://colab.research.google.com/github/Anchayadav/AutoTS/blob/main/Future_Salse_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas-profiling

# %%
import pandas as pd
import numpy  as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data=pd.read_csv('advertising.csv')
print(data.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(data.isnull().sum())
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
import plotly.express as px
import plotly.graph_objects as go

fig=px.scatter(data,x='Sales',y='TV',size='TV',trendline='ols')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from pandas_profiling import ProfileReport
profile=ProfileReport(data,title='pandas profile data')
profile.to_widgets()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas_profiling/profile_report.py:457: UserWarning:
#
# Ipywidgets is not yet fully supported on Google Colab (https://github.com/googlecolab/colabtools/issues/60).As an alternative, you can use the HTML report. See the documentation for more information.
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
profile.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8bf19b848b47> in <cell line: 1>()
# ----> 1 profile.to_notebook_iframe()
#
# NameError: name 'profile' is not defined

# %%
fig=px.scatter(data_frame=data,x='Sales',y='Newspaper',size='Newspaper',trendline='ols')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(data_frame=data,x='Sales',
               y='Radio',size='Radio',trendline='ols')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
correlation= data.corr()
print(correlation['Sales'].sort_values(ascending=False))
# Out:
# Sales        1.000000
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Name: Sales, dtype: float64

# %%
x=np.array(data.drop(['Sales'],axis=1))
y=np.array(data['Sales'])
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.10,random_state=42)

# %%
model=LinearRegression()
model.fit(xtrain,ytrain)
print(model.score(xtrain,ytrain))
# Out:
# 0.9008470190832933

# %%
features=np.array([[230.1,37.8,69.2]])
model.predict(features)
# Out:
# array([21.24465645])
